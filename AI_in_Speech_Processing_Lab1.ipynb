# %% [markdown]
# # Amal Krishna k

# %% [markdown]
# # BL.EN.U4AIE21008

# %% [markdown]
# Questions :
# A1. Load the recorded speech file into your python workspace. Once loaded, plot the graph for the
# speech signal.

# %%
# !pip install librosa

# %%
import librosa
y, sr = librosa.load(r"E:\AI in Speech\Lab\Lab1\audio.mp3")
librosa.display.waveshow(y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from glob import glob

import librosa
import librosa.display
import IPython.display as ipd

from itertools import cycle

sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %% [markdown]
# A2. Observe the length & magnitude range of the signal from the plot. Observing the plot, relate to
# the spoken words and silence between the words.

# %%
Duration = len(y) / sr  # Duration in seconds
print(f"Duration of the audio: {Duration:.2f} seconds")
print(f"Magnitude range: {y.min()} to {y.max()}")
# Out:
# Duration of the audio: 2.11 seconds
# Magnitude range: -0.883354663848877 to 0.8924660086631775

# %%
y, sr = librosa.load(r"E:\AI in Speech\Lab\Lab1\audio.mp3" , offset=0.0, duration=1.0)
y
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.08614756,
#        -0.08217171, -0.07784106], dtype=float32)

# %% [markdown]
# A3. Take a small segment of the signal and play it.

# %%
from IPython.display import Audio, display
audio1 = Audio(y, rate=sr)
display(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# A4. Play around with your recorded speech signal for various segments. Understand the nature of
# the signal. Also observe with abruptly segmented speech, how the perception of that speech is
# affected.

# %%
y, sr = librosa.load(r"E:\AI in Speech\Lab\Lab1\audio.mp3" , offset=1.0, duration=1.0)
audio2 = Audio(y, rate=sr)
display(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
